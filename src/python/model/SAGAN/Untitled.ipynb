# %%
import numpy as np 
from PIL import Image
from tensorflow.keras.preprocessing import image
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
last = np.load("last.npy")
last = last[19].reshape(64, 64, 3)
img = image.array_to_img(last, scale=True)

# %%
plt.imshow(img)
plt.show()

# %%
last = np.load("last.npy")[19]
first = np.load("first.npy")[19]

# %%
Image.fromarray(last, "RGB")
# Image.fromarray(first, "RGB")
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x130112630>

# %%
img.show()
