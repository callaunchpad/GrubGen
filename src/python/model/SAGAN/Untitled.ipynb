# %%
import numpy as np 
from PIL import Image
from tensorflow.keras.preprocessing import image
# %matplotlib inline
from matplotlib import pyplot as plt
import os
from moviepy.editor import ImageSequenceClip

# %%
pics = np.load("kevin_copy.npy")
for i in range(50): 
    pic = pics[i].reshape(64, 64, 3)
    img = image.array_to_img(pic, scale=True)
    plt.imshow(img)
    plt.show()

# %%
# last = np.load("last.npy")[1]
# first = np.load("first.npy")[19]

# %%
# Image.fromarray(last, "RGB")
# Image.fromarray(first, "RGB")

# %%
# img.show()

# %%
# from array2gif import write_gif

# %%
pics[1][0].shape
# Out:
# (64, 64, 3)

# %%
modified = []

# %%
for i in range(50): 
    normalized = np.rint(pics[i][0] * 127.5 + 127.5)
    modified.append(normalized)

# %%
modified[0].shape
# Out:
# (64, 64, 3)

# %%
import imageio

# %%
images = []
for img in modified:
    images.append(imageio.imread(img))
imageio.mimsave('/path/to/movie.gif', images)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-159-d019af4004ac> in <module>
#       1 images = []
#       2 for img in modified:
# ----> 3     images.append(imageio.imread(img))
#       4 imageio.mimsave('/path/to/movie.gif', images)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/imageio/core/functions.py in imread(uri, format, **kwargs)
#     219
#     220     # Get reader and read first
# --> 221     reader = read(uri, format, "i", **kwargs)
#     222     with reader:
#     223         return reader.get_data(0)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/imageio/core/functions.py in get_reader(uri, format, mode, **kwargs)
#     128
#     129     # Create request object
# --> 130     request = Request(uri, "r" + mode, **kwargs)
#     131
#     132     # Get format
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/imageio/core/request.py in __init__(self, uri, mode, **kwargs)
#     124
#     125         # Parse what was given
# --> 126         self._parse_uri(uri)
#     127
#     128         # Set extension
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/imageio/core/request.py in _parse_uri(self, uri)
#     238             if len(uri_r) > 60:
#     239                 uri_r = uri_r[:57] + "..."
# --> 240             raise IOError("Cannot understand given URI: %s." % uri_r)
#     241
#     242         # Check if this is supported
#
# OSError: Cannot understand given URI: array([[[141., 165.,  36.],
#         [ 96.,  25.,  62.],
#  ....
