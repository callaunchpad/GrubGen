# %%
import numpy as np
import scipy
disc_array = np.load('./ac-gan/discLoss3.npy')
gen_array = np.load('./ac-gan/genLoss3.npy')
samples_array = np.load('./ac-gan/samples3.npy')

print(disc_array.shape)
print(gen_array.shape)
print(samples_array.shape)
# Out:
# (10,)
# (10,)
# (10, 10, 64, 64, 1)

# %%
from matplotlib import pyplot as plt

plt.plot(disc_array)
plt.show()

# %%
plt.plot(gen_array)
plt.ylim(0, 5)
plt.show()

# %%
import matplotlib.image as mpimg
for k in samples_array:
    print(k[0][:,:,0].shape)
    for i in range(len(k)):
        plt.imshow(k[i][:,:,0])
        plt.show()
# Out:
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
