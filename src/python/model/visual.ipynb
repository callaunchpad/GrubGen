# %%
import numpy as np
import scipy
disc_array = np.load('./ac-gan/discLoss.npy')
gen_array = np.load('./ac-gan/genLoss.npy')
samples_array = np.load('./ac-gan/samples.npy')

print(disc_array.shape)
print(gen_array.shape)
print(samples_array.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-9ebc62860f27> in <module>()
#       3 disc_array = np.load('./ac-gan/discLoss.npy')
#       4 gen_array = np.load('./ac-gan/genLoss.npy')
# ----> 5 samples_array = scipy.imread('./ac-gan/samples.npy')
#       6
#       7 print(disc_array.shape)
#
# AttributeError: module 'scipy' has no attribute 'imread'

# %%
from matplotlib import pyplot as plt

plt.plot(disc_array)
plt.show()

# %%
plt.plot(gen_array)
plt.show()

# %%
import matplotlib.image as mpimg
print(samples_array.shape)
for k in samples_array:
    print(k.shape)
    print(k[0].shape)
    plt.imshow(k[0])
    plt.show()
# Out:
# (5, 1, 64, 64, 1)
# (1, 64, 64, 1)
# (64, 64, 1)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-213c91201637> in <module>()
#       4     print(k.shape)
#       5     print(k[0].shape)
# ----> 6     plt.imshow(k[0])
#       7     plt.show()
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3208                         filternorm=filternorm, filterrad=filterrad,
#    3209                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3210                         **kwargs)
#    3211     finally:
#    3212         ax._hold = washold
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
# ...
