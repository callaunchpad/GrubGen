# %%
import numpy as np
import scipy
disc_array = np.load('./ac-gan/discLoss2.npy')
gen_array = np.load('./ac-gan/genLoss2.npy')
samples_array = np.load('./ac-gan/samples2.npy')

print(disc_array.shape)
print(gen_array.shape)
print(samples_array.shape)
# Out:
# (5,)
# (5,)
# (5, 1, 64, 64, 1)

# %%
from matplotlib import pyplot as plt

plt.plot(disc_array)
plt.show()

# %%
plt.plot(gen_array)
plt.show()

# %%
import matplotlib.image as mpimg
for k in samples_array:
    print(k[0][:,:,0].shape)
    plt.imshow(k[0][:,:,0])
    plt.show()
# Out:
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
